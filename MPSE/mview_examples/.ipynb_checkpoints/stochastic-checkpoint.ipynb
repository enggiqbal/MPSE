# %% [markdown]
# # Running MPSE Using a Stochastic Gradient Descent Scheme

# %%
import sys; sys.path.insert(0,"../")

import mview

# %% [markdown]
# Minimizing the MPSE stress function by computing the full gradient at each point is very slow. It is also very ill-guided, as our goal is to compute $(N+6)*K$ parameters (in the default setting), which shouldn't require $O(N^2)$ quantities per iteration.

# %% [markdown]
# In all of these experiments, the set of dissimilarity relations used will be those of 1028 nodes, with random positions in 3D space, observed from 3 different perspectives, each given by projection of the 3D positions into 2D positions by one of the standard projection matrix.
#
# Instead of computing the whole dissimilarity matrices, we will just ask the MPSE class to compute them as the need arises (details on this later). This by itself means that we'll be able to compute the solution in less time than what it takes to compute the distance matrices.

# %%
DD = {
    'nodes' : 1028,
    'attributes' : 3,
    'Q' : 'standard'
    } 
#this dictionary defines the dissimilarity relations

# %% [markdown]
# The level of stochasticity is given by average_neighbors, which is the average number of neighbors per node used in computing the stress and gradient at each iteration.

# %%
mv = mview.basic(DD,
                 average_neighbors=3,
                 max_iter=200, min_grad=1e-5,
                 verbose=2)
# Out:
# mpse.MPSE():
#   MPSE.initialize():
#     X0 : random
#     Q0 : random
#   dissimilarity stats:
#     number of views : 3
#     number of points : 1028
#   embedding stats:
#     embedding dimension : 3
#     projection dimension : 2
#   MPSE.gd():
#     mpse method : optimize all
#     initial stress : 8.10e-01
# gd.multiple():
#   computation parameters:
#     stochastic : True
#     constraint : True
#     projected : [False, True]
#     scheme : ['mm', 'mm']
#     initial lr : [1, 1]
#     min_grad : 1.00e-05
#     max_iter : 200
#     max_step : 1.00e+04
#   progress:
# 200 : step = 5.17e-07, grad = 1.06e-05, cost = 8.33e-07, lr = 7.25e-01
#   results:
#     conclusion : minimum gradient size reached
#     total iterations : 189
#     final cost : 8.33e-07
#     time : 3.67e+01 [sec]
#   Final stress : 1.04e-06

# %% [markdown]
# The final (normalized) MPSE stress is:

# %%
print(mv.cost)
# Out:
# 1.0421832006320793e-06

# %% [markdown]
# The computation time (in seconds) is (fast!):

# %%
print(mv.time)
# Out:
# 36.732168436050415

# %% [markdown]
# The following are plots of the final embedding, projections, and computation history.
#
# Note: The color in the plots was added automatically (by order of the 1st components in each of the true projection images). The more 'organized' the color, the better the embedding.
#
# Note: The algorithm treats the projection matrices $Q$ as one $3x2x3$ array. The embedding $X$ and the projection paramters $Q$ each have their own gradient size, learning rate, and step size (its a coordinate gradient descent implementation).

# %%
mv.figureX()
mv.figureY()
mv.figureH()
