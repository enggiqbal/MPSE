# %% [markdown]
# # Introduction to mview

# %% [markdown]
# In this notebook, I'll give some examples on how to use the mview module, which we use to solve Multi-Perspective Simultaneous Embedding (MPSE) problems.
#
# We will limit ourselves to using the function mview.basic(), which makes it easy to run an MPSE algorithm in a single line.

# %%
# Modules needed:
import numpy as np
# %matplotlib notebook
 
# Add mview:
import sys; sys.path.insert(0,"../") #adds parent folder to list of module directories
import mview

# %% [markdown]
# We will use a '123' data set for our experiments:

# %%
path = 'data/123/input/'
Y1 = np.genfromtxt(path+'spicy_rice_1000_1.csv', delimiter=',')
Y2 = np.genfromtxt(path+'spicy_rice_1000_2.csv', delimiter=',')
Y3 = np.genfromtxt(path+'spicy_rice_1000_3.csv', delimiter=',')
fig, ax = plt.subplots(1,3)
ax[0].plot(Y1[:,0],Y1[:,1],'o')
ax[1].plot(Y2[:,0],Y2[:,1],'o')
ax[2].plot(Y3[:,0],Y3[:,1],'o')
plt.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The data that we will provide to mview.basic() is the list [Y1,Y2,Y3], which tells the algorithm that we wish to embedd three perspectives w/ the given perspective features/coordinates.
#
# Each element of this list can be an array containing features, a square matrix containing distances, or a 1D array containing condensed distances, among others. I will give examples of different inputs in a different notebook.

# %% [markdown]
# ## Example: mds-mpse (solve for both embedding and projections)

# %% [markdown]
# Here we run mview.basic with default parameters. The default choice of parameters seems to work well for many examples. By default, mview.basic uses:
# 1) MDS-MPSE cost function
# 2) smart initialization, by solving a combined MDS problem w/ adaptive SGD
# 3) stochastic gradient descent with adaptive learning rate, w/ batch size equal to 10

# %%
mv = mview.basic([Y1,Y2,Y3],verbose=2)
mv.plot_embedding()
mv.plot_projections()
mv.plot_computations()
plt.draw()
# Out:
# mview.MPSE():
#   data details:
#     number of perspectives : 3
#     number of samples : 1000
#   visualization details:
#     embedding dimension : 3
#     image dimension : 2
#     visualization type : mds
#   setup visualization instance for perspective 1 :
#     mview.MDS():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#     initial embedding : random
#     initial stress : 9.95e-04
#   setup visualization instance for perspective 2 :
#     mview.MDS():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#     initial embedding : random
#     initial stress : 9.20e-04
#   setup visualization instance for perspective 3 :
#     mview.MDS():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#     initial embedding : random
#     initial stress : 9.19e-04
#   initialize:
#     fixed embedding : False
#     initial embedding : random
#     fixed projections : False
#     initial projections : random
#   MPSE.smart_initialize():
#     mview.MDS():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 3
#     initial embedding : given
#     initial stress : 1.03e-03
#       MDS.gd():
#         specs:
#           gradient type : batch
#           batch size : 10
#         gd.single():
#           computation parameters:
#             stochastic : True
#             constraint : False
#             scheme : mm
#             initial lr : 1
#             max_iter : 100
#             max_step : 1.00e+10
#           progress:
#             iter:      cost:     grad:     lr:       step:
#              100/ 100  2.96e-05  4.68e-03  8.40e-01  3.93e-03
#           results:
#             conclusion : maximum number of iterations reached
#             total iterations : 100
#             final cost : 2.96e-05
#             final gradient size : 4.68e-03
#             final learning rate : 8.40e-01
#             final step size : 3.93e-03
#             time : 4.59e+00 [sec]
#         final stress : 1.99e-05
#     gd.single():
#       computation parameters:
#         stochastic : True
#         constraint : True
#         scheme : mm
#         initial lr : 0.1
#         max_iter : 50
#         max_step : 1.00e+10
#       progress:
#         iter:      cost:     grad:     lr:       step:
#           50/  50  1.26e-04  2.72e+00  9.57e-03  2.60e-02
#       results:
#         conclusion : maximum number of iterations reached
#         total iterations : 50
#         final cost : 1.26e-04
#         final gradient size : 2.72e+00
#         final learning rate : 9.57e-03
#         final step size : 2.60e-02
#         time : 6.36e+00 [sec]
#   MPSE.gd():
#       initial stress : 8.20e-04
#       fixed : None
#       batch size : 10
#     gd.multiple():
#       computation parameters:
#         stochastic : True
#         constraint : True
#         projected : [False, True]
#         scheme : ['mm', 'mm']
#         initial lr : 1.00e+00, 1.00e-02
#         max_iter : 100
#         max_step : 1.00e+10
#       progress:
#         iter:      cost:     grad:     lr:       step:
#          100/ 100  5.51e-07  1.21e-02  8.62e-01  1.12e-04
#       results:
#         conclusion : maximum number of iterations reached
#         total iterations : 100
#         final cost : 5.51e-07
#         time : 1.34e+01 [sec]
#     final cost : 3.65e-07
#     individual costs : 3.35e-07, 3.78e-07, 3.81e-07
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ## Example: TSNE-MPSE

# %%
mv = mview.basic([Y1,Y2,Y3],visualization_method='tsne',verbose=2)
mv.plot_embedding()
mv.plot_projections()
mv.plot_computations()
# Out:
# mview.MPSE():
#   data details:
#     number of perspectives : 3
#     number of samples : 1000
#   visualization details:
#     embedding dimension : 3
#     image dimension : 2
#     visualization type : tsne
#   setup visualization instance for perspective 1 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#         perplexity : 30.00
#   setup visualization instance for perspective 2 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#         perplexity : 30.00
#   setup visualization instance for perspective 3 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#         perplexity : 30.00
#   initialize:
#     fixed embedding : False
#     initial embedding : random
#     fixed projections : False
#     initial projections : random
#   MPSE.smart_initialize():
#     mview.MDS():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 3
#     initial embedding : given
#     initial stress : 1.01e-03
#       MDS.gd():
#         specs:
#           gradient type : batch
#           batch size : 10
#         gd.single():
#           computation parameters:
#             stochastic : True
#             constraint : False
#             scheme : mm
#             initial lr : 1
#             max_iter : 100
#             max_step : 1.00e+10
#           progress:
#             iter:      cost:     grad:     lr:       step:
#              100/ 100  1.26e-05  2.10e-03  8.87e-01  1.86e-03
#           results:
#             conclusion : maximum number of iterations reached
#             total iterations : 100
#             final cost : 1.26e-05
#             final gradient size : 2.10e-03
#             final learning rate : 8.87e-01
#             final step size : 1.86e-03
#             time : 5.02e+00 [sec]
#         final stress : 8.60e-06
#     gd.single():
#       computation parameters:
#         stochastic : True
#         constraint : True
#         scheme : mm
#         initial lr : 0.1
#         max_iter : 50
#         max_step : 1.00e+10
#       progress:
#         iter:      cost:     grad:     lr:       step:
#           50/  50  5.09e-02  9.90e+00  1.41e+01  1.39e+02
#       results:
#         conclusion : maximum number of iterations reached
#         total iterations : 50
#         final cost : 5.09e-02
#         final gradient size : 9.90e+00
#         final learning rate : 1.41e+01
#         final step size : 1.39e+02
#         time : 6.76e+00 [sec]
#   MPSE.gd():
#       initial stress : 3.61e+00
#       fixed : None
#     gd.multiple():
#       computation parameters:
#         stochastic : False
#         constraint : True
#         projected : [False, True]
#         scheme : ['mm', 'mm']
#         initial lr : 1.00e+02, 1.00e+01
#         max_iter : 100
#         max_step : 1.00e+10
#       progress:
#         iter:      cost:     grad:     lr:       step:
#          100/ 100  1.27e+00  3.74e-01  5.22e+02  7.70e-02
#       results:
#         conclusion : maximum number of iterations reached
#         total iterations : 100
#         final cost : 1.27e+00
#         time : 1.59e+01 [sec]
#     final cost : 1.25e+00
#     individual costs : 1.43e+00, 9.75e-01, 1.32e+00
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
