# %% [markdown]
# # Examples of MPSE-tsne using mview.basic()

# %%
import sys; sys.path.insert(0,"../")
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib notebook

import mview

# %% [markdown]
# We'll use our 1000 point 123 data set:

# %%
path = 'data/123/input/'
X_true = np.genfromtxt(path+'spicy_rice_1000_123.csv', delimiter=',')
Y1 = np.genfromtxt(path+'spicy_rice_1000_1.csv', delimiter=',')
Y2 = np.genfromtxt(path+'spicy_rice_1000_2.csv', delimiter=',')
Y3 = np.genfromtxt(path+'spicy_rice_1000_3.csv', delimiter=',')
fig, ax = plt.subplots(1,3)
ax[0].plot(Y1[:,0],Y1[:,1],'o')
ax[1].plot(Y2[:,0],Y2[:,1],'o')
ax[2].plot(Y3[:,0],Y3[:,1],'o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="852.75">

# %% [markdown]
# We run mpse-tsne using mview.basic() just as we do for mpse-mds. We just set 'visualization_method' = 'tsne'.
#
# The line below will run mpse-tsne with standard parameters (the same as in mpse-mds, with perplexity = 30).

# %%
mv = mview.basic([Y1,Y2,Y3], visualization_method = 'tsne', verbose=2)
# Out:
# mview.MPSE():
#   data details:
#     number of perspectives : 3
#     number of samples : 1000
#   visualization details:
#     embedding dimension : 3
#     image dimension : 2
#     visualization type : tsne
#   setup visualization instance for perspective 1 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#         perplexity : 30.00
#       TSNE.initialize():
#         method : random
#         initial cost : 7.39e+00
#   setup visualization instance for perspective 2 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#         perplexity : 30.00
#       TSNE.initialize():
#         method : random
#         initial cost : 6.67e+00
#   setup visualization instance for perspective 3 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
# ...

# %%
mv.plot_images()
# Out:
# <img src="data:image/png;base64,..." width="1198.5">

# %%
mv.plot_embedding()
# Out:
# <img src="data:image/png;base64,..." width="499.5">

# %% [markdown]
# To change the perplexity, we specify visualization_args = {'perplexity':###}."

# %%
mv = mview.basic([Y1,Y2,Y3], visualization_method = 'tsne', visualization_args = {'perplexity':500}, verbose=2)
# Out:
# mview.MPSE():
#   data details:
#     number of perspectives : 3
#     number of samples : 1000
#   visualization details:
#     embedding dimension : 3
#     image dimension : 2
#     visualization type : tsne
#   setup visualization instance for perspective 1 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#         perplexity : 500.00
#       TSNE.initialize():
#         method : random
#         initial cost : 1.63e+00
#   setup visualization instance for perspective 2 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#         perplexity : 500.00
#       TSNE.initialize():
#         method : random
#         initial cost : 1.66e+00
#   setup visualization instance for perspective 3 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
# ...

# %%
mv.plot_images()
# Out:
# <img src="data:image/png;base64,..." width="1198.5">

# %%
mv.plot_embedding()
# Out:
# <img src="data:image/png;base64,..." width="499.5">

# %% [markdown]
# Other arguments work too, such as smart visualization (initialize using mds on the combined distances) or batch_size.

# %%
mv = mview.basic([Y1,Y2,Y3], visualization_method='tsne', visualization_args={'perplexity':500}, 
                 smart_initialization=True, batch_size=50, verbose=2)
# Out:
# mview.MPSE():
#   data details:
#     number of perspectives : 3
#     number of samples : 1000
#   visualization details:
#     embedding dimension : 3
#     image dimension : 2
#     visualization type : tsne
#   setup visualization instance for perspective 1 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#         perplexity : 500.00
#       TSNE.initialize():
#         method : random
#         initial cost : 1.63e+00
#   setup visualization instance for perspective 2 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
#         embedding dimension : 2
#         perplexity : 500.00
#       TSNE.initialize():
#         method : random
#         initial cost : 1.65e+00
#   setup visualization instance for perspective 3 :
#     mview.TSNE():
#       data details:
#         number of samples : 1000
#       embedding details:
# ...

# %%
mv.plot_images()
# Out:
# <img src="data:image/png;base64,..." width="1198.5">

# %%
mv.plot_embedding()
# Out:
# <img src="data:image/png;base64,..." width="499.5">
